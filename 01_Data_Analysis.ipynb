# %%
import pandas as pd
import numpy as np

# %%
ds=pd.Series([1,2,3,4,5],index=['v','h','a','b','s'],dtype='int',name='yash')
print(ds)
# Out:
# v    1
# h    2
# a    3
# b    4
# s    5
# Name: yash, dtype: int32

# %%
ds=pd.Series((1,2,3,4,5),index=['v','h','a','b','s'],dtype='int',name='yash')
print(ds)
# Out:
# v    1
# h    2
# a    3
# b    4
# s    5
# Name: yash, dtype: int32

# %%
ds=pd.Series({"name":"yash","age":"21"},dtype='int')
print(ds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5e4344acf11d> in <module>
# ----> 1 ds=pd.Series({"name":"yash","age":"21"},dtype='int')
#       2 print(ds)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     279                 data = data._mgr
#     280             elif is_dict_like(data):
# --> 281                 data, index = self._init_dict(data, index, dtype)
#     282                 dtype = None
#     283                 copy = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _init_dict(self, data, index, dtype)
#     368
#     369         # TODO: passing np.float64 to not break anything yet. See GH-17261
# --> 370         s = create_series_with_explicit_dtype(
#     371             values, index=keys, dtype=dtype, dtype_if_empty=np.float64
# ...

# %%
a=np.array([1,2,3,4])
ds=pd.Series(a,index=['v','h','a','b'],dtype='int',name='yash')
print(ds)

# %%
ds=pd.DataFrame([['a','b','c','d'],[1,2,3],[5,6,7]],index=['p','q','r'],columns=['y','a','s','h'])
print(ds)

# %%
ds=pd.DataFrame((('a','b','c','d'),(1,2,3),(5,6,7)),index=['p','q','r'],columns=['y','a','s','h'])
print(ds)

# %%
ds=pd.DataFrame({'name':['y','a','s','h'],'mark':[10,20,30,40],index=['p','q','r','a'])
print(ds)

# %%
print(ds.name)
# Out:
# yash

# %%
ds=pd.read_csv('train.csv')

# %%
print(ds)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ds.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
ds.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
ds.size
# Out:
# 10692

# %%
ds.shape
# Out:
# (891, 12)

# %%
ds.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
ds.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
ds.ndim
# Out:
# 2

# %%
ds.T
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                               22
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                         38
# ...

# %%
ds.T
# Out:
# Name        Braund, Mr. Owen Harris  \
# PassengerId                       1
# Survived                          0
# Pclass                            3
# Sex                            male
# Age                              22
# SibSp                             1
# Parch                             0
# Ticket                    A/5 21171
# Fare                           7.25
# Cabin                           NaN
# Embarked                          S
#
# Name        Cumings, Mrs. John Bradley (Florence Briggs Thayer)  \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Sex                                                     female
# Age                                                         38
# SibSp                                                        1
# Parch                                                        0
# ...

# %%
ds=ds.set_index('Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-a0878e2f92ae> in <module>
# ----> 1 ds=ds.set_index('Name')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['Name'] are in the columns"

# %%
ds.reset_index()
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
print(ds)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
temp=pd.read_csv('train.csv')

# %%
df1=pd.DataFrame({'name':['a','b','c'],'marks':[1,2,3],'cgpa':[1,2,3]})

# %%
df1=df1.set_index("name",drop=False)

# %%
df1=df1.set_index("name")
print(df1)
# Out:
#       marks  cgpa
# name
# a         1     1
# b         2     2
# c         3     3

# %%
df1=df1.reset_index()

# %%
print(df1)
# Out:
#   name  marks  cgpa
# 0    a      1     1
# 1    b      2     2
# 2    c      3     3

# %%
df=pd.read_csv('train.csv')

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
a=pd.DataFrame(df['Name'],df['Pclass'])

# %%
print(a)
# Out:
#                                                      Name
# Pclass
# 3            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...                                                   ...
# 2                                  Heikkinen, Miss. Laina
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3            Futrelle, Mrs. Jacques Heath (Lily May Peel)
#
# [891 rows x 1 columns]

# %%
type(df[['Name','Pclass']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Name','Pclass']]
# Out:
#                                                   Name  Pclass
# 0                              Braund, Mr. Owen Harris       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                             Allen, Mr. William Henry       3
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas       2
# 887                       Graham, Miss. Margaret Edith       1
# 888           Johnston, Miss. Catherine Helen "Carrie"       3
# 889                              Behr, Mr. Karl Howell       1
# 890                                Dooley, Mr. Patrick       3
#
# [891 rows x 2 columns]

# %%
df.iloc[2]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                                26
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[2,3]
# Out:
# 'Heikkinen, Miss. Laina'

# %%
df.iloc[1:10,2:5]
# Out:
#    Pclass                                               Name     Sex
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2       3                             Heikkinen, Miss. Laina  female
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       3                           Allen, Mr. William Henry    male
# 5       3                                   Moran, Mr. James    male
# 6       1                            McCarthy, Mr. Timothy J    male
# 7       3                     Palsson, Master. Gosta Leonard    male
# 8       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9       2                Nasser, Mrs. Nicholas (Adele Achem)  female

# %%
df.iloc[:,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=df.set_index('Name')

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.loc["Braund, Mr. Owen Harris":"Montvila, Rev. Juozas"]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Dahlberg, Miss. Gerda Ulrika                                883         0
# Banfield, Mr. Frederick James                               884         0
# Sutehall, Mr. Henry Jr                                      885         0
# Rice, Mrs. William (Margaret Norton)                        886         0
# Montvila, Rev. Juozas                                       887         0
#
# ...

# %%
df1=pd.DataFrame({'P':[10,20,30],'Q':[40,50,60],'R':[70,80,90]},index=['A',"B",'C'])

# %%
df1
# Out:
#     P    Q   R
# A  10   40  70
# B  20  100  80
# C  30   60  90

# %%
df1.iloc[1,1]
# Out:
# 50

# %%
df1.loc['B',"Q"]=100

# %%
df1.loc['B']
# Out:
# P    20
# Q    50
# R    80
# Name: B, dtype: int64

# %%
df1.loc[['A','B','C'],'R']
# Out:
# A    70
# B    80
# C    90
# Name: R, dtype: int64

# %%
df1['D']=7

# %%
df1
# Out:
#     P    Q   R  D
# A  10   40  70  7
# B  20  100  80  7
# C  30   60  90  7

# %%
df1['D']=[1,2,3]

# %%
df1
# Out:
#     P    Q   R  D
# A  10   40  70  1
# B  20  100  80  2
# C  30   60  90  3
